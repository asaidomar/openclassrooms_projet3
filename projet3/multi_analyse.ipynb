# %%
import operator
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as st

from  pathlib import Path
import projet3

# %%
sns.set(color_codes=True)

# %%
result_folder = Path(projet3.__file__).with_name("results")
data_src_folder = Path(projet3.__file__).with_name("data")

# %%
data = pd.read_csv(result_folder.joinpath("complete_data.csv"))

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127292 entries, 0 to 127291
# Data columns (total 13 columns):
# calcium_100g          127292 non-null float64
# cholesterol_100g      127292 non-null float64
# trans-fat_100g        127292 non-null float64
# iron_100g             127292 non-null float64
# vitamin-c_100g        127292 non-null float64
# vitamin-a_100g        127292 non-null float64
# fat_100g              127292 non-null float64
# saturated-fat_100g    127292 non-null float64
# sugars_100g           127292 non-null float64
# carbohydrates_100g    127292 non-null float64
# proteins_100g         127292 non-null float64
# salt_100g             127292 non-null float64
# sodium_100g           127292 non-null float64
# dtypes: float64(13)
# memory usage: 12.6 MB

# %%
sns.pairplot(data[["calcium_100g", "cholesterol_100g", "iron_100g",
                   "trans-fat_100g", "fat_100g", "saturated-fat_100g",
                   "salt_100g", "sodium_100g", "sugars_100g",
                   "carbohydrates_100g", "proteins_100g"]])

# %%
# correlation sodium, "salt_100g"
# correlation "saturated-fat_100g", "fat_100g"
#corr = st.pearsonr(data["sodium_100g"], data["salt_100g"])[0]

# %%
#corr = st.pearsonr(data["saturated-fat_100g"], data["fat_100g"])[0]
data.select_dtypes(include=np.number).corr()
# Out:
#                     calcium_100g  cholesterol_100g  trans-fat_100g  iron_100g  \
# calcium_100g            1.000000          0.010208       -0.001823   0.170875
# cholesterol_100g        0.010208          1.000000       -0.000476  -0.000522
# trans-fat_100g         -0.001823         -0.000476        1.000000  -0.000267
# iron_100g               0.170875         -0.000522       -0.000267   1.000000
# vitamin-c_100g          0.036810         -0.002573       -0.001681   0.008858
# vitamin-a_100g          0.284373         -0.000127       -0.000174   0.069402
# fat_100g                0.040245          0.026280        0.023260  -0.000500
# saturated-fat_100g      0.065853          0.046661        0.010984  -0.001970
# sugars_100g            -0.015239         -0.019408        0.004583   0.011522
# carbohydrates_100g     -0.031350         -0.038154        0.007262   0.013178
# proteins_100g           0.089846          0.051482       -0.010780   0.001317
# ...

# %%
sns.heatmap(data.select_dtypes(include=np.number).corr())

# %%
sns.set(style="whitegrid")

# %%
columns_ = ["calcium_100g", "cholesterol_100g", "iron_100g",
                   "trans-fat_100g", "fat_100g", "saturated-fat_100g",
                   "salt_100g", "sodium_100g", "sugars_100g",
                   "carbohydrates_100g", "proteins_100g"]

# %%
data[columns_].describe()
len(data)

# print(data[columns_] > 0.0) vs data > 0.0
# Out:
# 127292

# %%
filtered_data = data[(data >= 0.0)&(data <= 100)]
filtered_data.info()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127292 entries, 0 to 127291
# Data columns (total 13 columns):
# calcium_100g          127291 non-null float64
# cholesterol_100g      127292 non-null float64
# trans-fat_100g        127285 non-null float64
# iron_100g             127291 non-null float64
# vitamin-c_100g        127291 non-null float64
# vitamin-a_100g        127292 non-null float64
# fat_100g              127287 non-null float64
# saturated-fat_100g    127290 non-null float64
# sugars_100g           127285 non-null float64
# carbohydrates_100g    127282 non-null float64
# proteins_100g         127291 non-null float64
# salt_100g             127130 non-null float64
# sodium_100g           127171 non-null float64
# dtypes: float64(13)
# memory usage: 12.6 MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127292 entries, 0 to 127291
# Data columns (total 13 columns):
# calcium_100g          127292 non-null float64
# cholesterol_100g      127292 non-null float64
# ...

# %%
columns_ = filtered_data.columns
n = len(columns_)
fig, ax = plt.subplots(len(columns_), 1, figsize=(12, n*6), sharex=True)

for i, c in enumerate(columns_):
    plt.sca(ax[i])
    ax_ = sns.boxplot(data=filtered_data[c])
    ax_.set_title(c)
    plt.ylabel(c)
    #ax.show()
